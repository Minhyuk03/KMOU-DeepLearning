# %% [markdown]
# <a href="https://colab.research.google.com/github/Minhyuk03/KMOU-DeepLearning/blob/main/00testfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안요?")
# Out:
# 안요?
